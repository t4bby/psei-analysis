# %% [markdown]
# ## Install Python Dependencies
# This installs the packages and libraries that Python needed inorder to analyze and download the data

# %% [markdown]
# # Import Python Packages
# This will import the dependencies to be used to download and analyze the data that will be downloaded through the Yahoo Finance API.
#
# ### Yahoo Finance API
# ```
# pip install yfinance
# ```
#
# ### Dataframe
# ```
# pip install pandas
# ```
#
# ### Data Reader
# ```
# pip install pandas_datareader
# ```
#
# ### Numerical Python
# ```
# pip install numpy
# ```
#
# ### Plotting Data
# ```
# pip install plotly matplotlib
# ```
#
# ### Machine learning for implementation of Logistic Regression
# ```
# pip install scikit-learn
# ```
#
# ### Technical Analysis Library
# ```
# pip install ta-lib
# ```

# %%
import yfinance as yf   # Yahoo Finance API
import pandas as pd     # DataFrame
import numpy as np      # Numerical Python
from pandas_datareader import data as pdr # Pandas Data Reader
import talib as ta      # Technical Analysis Library

# Machine learning
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score

# Widgets for Dynamic Graphs
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### Library Options
# This will set the options for the libraries that will be used in this notebook

# %%
yf.pdr_override()   # Override Yahoo Finance API output to use pandas data reader
pd.options.plotting.backend = "plotly" # Use plotly as the plotting backend

# %% [markdown]
# ### Download PSEi Data
# This will download the data from Yahoo Finance API and then import it to pandas dataframe.
# The data will be downloaded is from `2000-01-01` to `2023-05-18`

# %%
df = pdr.get_data_yahoo('PSEI.PS', '2000-01-01', '2023-05-18')
df = df.dropna()
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  2143.669922  2148.709961  2122.989990  2141.770020  2141.219482
# 2000-01-04  2151.550049  2158.209961  2130.679932  2153.179932  2152.626465
# 2000-01-05  2113.379883  2113.379883  2070.139893  2074.750000  2074.216553
# 2000-01-06  2079.050049  2082.810059  2066.879883  2079.110107  2078.575684
# 2000-01-07  2079.320068  2094.290039  2077.649902  2094.290039  2093.751709
#
#             Volume
# Date
# 2000-01-03       0
# 2000-01-04       0
# 2000-01-05       0
# 2000-01-06       0
# 2000-01-07       0

# %% [markdown]
# ### Output the raw data to CSV

# %%
df.to_csv('raw.csv')

# %% [markdown]
# # Initialize Variables
#
# ### Time Period
# The window size (moving average in days) of the rolling mean and rolling correlation
#
# ### Train Size
# The percentage of the data that will be used for training the model

# %%
timeperiod = widgets.IntSlider(description="Time Period", min=2, max=100, step=1, value=10)
trainsize = widgets.FloatSlider(description="Train Size",min=0, max=1, step=0.01, value=0.7)

display(timeperiod, trainsize)
# Out:
# IntSlider(value=10, description='Time Period', min=2)
# FloatSlider(value=0.8, description='Train Size', max=1.0, step=0.01)

# %%
df['S_' + str(timeperiod.value)] = df['Close'].rolling(window=timeperiod.value).mean() # Rolling mean

df['Corr'] = df['Close'].rolling(window=timeperiod.value).corr(df['S_' + str(timeperiod.value)]) # Correlation between the close price and the rolling mean

df['RSI'] = ta.RSI(np.array(df['Close']), timeperiod=timeperiod.value) # Relative Strength Index

df['Open-Close'] = df['Open'] - df['Close'].shift(1) # The difference between the current day's open and the previous day's close

df['Open-Open'] = df['Open'] - df['Open'].shift(1) # The difference between the current day's open and the previous day's open

df = df.dropna() # Drop the NaN values
df #    Show the dataframe
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-02-22  1833.839966  1833.839966  1778.890015  1799.829956  1799.367310
# 2000-02-23  1799.540039  1835.810059  1799.540039  1828.930054  1828.459839
# 2000-02-24  1831.420044  1835.609985  1787.219971  1794.810059  1794.348633
# 2000-02-25  1831.420044  1835.609985  1787.219971  1794.810059  1794.348633
# 2000-02-28  1753.619995  1753.619995  1711.719971  1720.650024  1720.207642
# ...                 ...          ...          ...          ...          ...
# 2023-05-11  6669.399902  6704.529785  6657.509766  6675.459961  6675.459961
# 2023-05-12  6661.600098  6668.649902  6578.149902  6578.149902  6578.149902
# 2023-05-15  6582.569824  6585.720215  6523.149902  6523.149902  6523.149902
# 2023-05-16  6549.339844  6596.339844  6549.339844  6588.899902  6588.899902
# 2023-05-17  6595.459961  6644.379883  6593.660156  6635.109863  6635.109863
#
#             Volume         S_10      Corr        RSI  Open-Close  Open-Open  \
# Date
# 2000-02-22       0  1926.203992  0.863339  21.720313    0.000000 -48.690063
# 2000-02-23       0  1904.369995  0.860742  30.785458   -0.289917 -34.299927
# 2000-02-24       0  1881.835999  0.883831  26.749769    2.489990  31.880005
# 2000-02-25       0  1861.596008  0.887208  26.749769   36.609985   0.000000
# 2000-02-28       0  1835.987012  0.934438  19.788826  -41.190063 -77.800049
# ...            ...          ...       ...        ...         ...        ...
# 2023-05-11  116400  6641.555029  0.427915  59.636713   10.810059  36.569824
# 2023-05-12  150400  6641.002002 -0.082792  47.087081  -13.859863  -7.799805
# 2023-05-15   78700  6630.808984 -0.315707  41.590710    4.419922 -79.030273
# 2023-05-16   65700  6622.429980 -0.206046  49.431267   26.189941 -33.229980
# 2023-05-17  103100  6625.271973 -0.432961  54.229167    6.560059  46.120117
#
#             Predicted_Signal  PSEi_returns  Strategy_Returns
# Date
# 2000-02-22                 1     -0.018720         -0.018720
# 2000-02-23                 1      0.016039          0.016039
# 2000-02-24                 1     -0.018832         -0.018832
# 2000-02-25                 1      0.000000          0.000000
# 2000-02-28                 1     -0.042197         -0.042197
# ...                      ...           ...               ...
# 2023-05-11                 1      0.002530          0.002530
# 2023-05-12                 1     -0.014685         -0.014685
# 2023-05-15                 1     -0.008396         -0.008396
# 2023-05-16                 1      0.010029          0.010029
# 2023-05-17                 1      0.006989          0.006989
#
# [5766 rows x 14 columns]

# %% [markdown]
# ### Prepare the data for the model

# %%
x = df.iloc[:,:9] # The features that will be used for the model
y = np.where(df['Close'].shift(-1) > df['Close'],1,-1) # 1 if the price goes up, -1 otherwise

# %%
split = int(trainsize.value * len(df)) # Split the data into train and test set
x_train, x_test, y_train, y_test = x[:split], x[split:], y[:split], y[split:] # Split the data into train and test set

# %% [markdown]
# ### Implement Logistic Regression

# %%
model = LogisticRegression()  # Initialize the model
model = model.fit(x_train, y_train)  # Fit the model

# %% [markdown]
# ### Show the model

# %%
# Show the coefficients of the model
pd.DataFrame(zip(x.columns, np.transpose(model.coef_)))
# 1st column is the features, 2nd column is the coefficients
# Out:
#            0                          1
# 0       Open    [2.267669299178034e-06]
# 1       High   [2.2920127155775336e-06]
# 2        Low     [2.26819802646283e-06]
# 3      Close    [2.287727248966235e-06]
# 4  Adj Close    [2.287139176882533e-06]
# 5     Volume  [-3.3721335887791688e-09]
# 6       S_10    [2.304098079965185e-06]
# 7       Corr    [6.660079868362076e-11]
# 8        RSI   [1.3752387347115249e-08]

# %% [markdown]
# ### Predict the price

# %%
probability = model.predict_proba(x_test) # Show the probability of the model

# %%
probability # 1st column is the probability of the price going down, 2nd column is the probability of the price going up
# Out:
# array([[0.47344444, 0.52655556],
#        [0.47347594, 0.52652406],
#        [0.47336541, 0.52663459],
#        ...,
#        [0.47759671, 0.52240329],
#        [0.47751342, 0.52248658],
#        [0.47741185, 0.52258815]])

# %%
y_predicted = model.predict(x_test) # Predict the price

# %%
metrics.confusion_matrix(y_test, y_predicted) # Show the confusion matrix
# Out:
# array([[  1, 562],
#        [  0, 591]], dtype=int64)

# %% [markdown]
# ### Show the accuracy of the model

# %%
print("Accuracy:", model.score(x_test,y_test)) # Show the accuracy of the model
# Out:
# Accuracy: 0.512998266897747

# %%
metrics.classification_report(y_test, y_predicted) # Show the classification report
# Out:
# '              precision    recall  f1-score   support\n\n          -1       1.00      0.00      0.00       563\n           1       0.51      1.00      0.68       591\n\n    accuracy                           0.51      1154\n   macro avg       0.76      0.50      0.34      1154\nweighted avg       0.75      0.51      0.35      1154\n'

# %% [markdown]
# ### Show the cross validation score

# %%
cross_val = cross_val_score(LogisticRegression(), x, y, scoring='accuracy', cv=10) # Show the cross validation score
cross_val
# Out:
# array([0.50779896, 0.50606586, 0.49046794, 0.50606586, 0.52686308,
#        0.50606586, 0.50694444, 0.50868056, 0.50868056, 0.50694444])

# %%
df['Predicted_Signal'] = model.predict(x) # Predict the signal
df['PSEi_returns'] = np.log(df['Close'] / df['Close'].shift(1)) # Calculate the PSEi returns
Cumulative_PSEi_returns = np.cumsum(df[split:]['PSEi_returns']) # Calculate the cumulative PSEi returns

df['Strategy_Returns'] = df['PSEi_returns'] * df['Predicted_Signal'].shift(1) # Calculate the strategy returns
Cumulative_Strategy_returns = np.cumsum(df[split:]['Strategy_Returns']) # Calculate the cumulative strategy returns
# Out:
# C:\Users\Tabby\AppData\Local\Temp\ipykernel_17108\3743937999.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Tabby\AppData\Local\Temp\ipykernel_17108\3743937999.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Tabby\AppData\Local\Temp\ipykernel_17108\3743937999.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Output the data to CSV

# %%
df.to_csv('predicted signals.csv') # Output the data to CSV

# %% [markdown]
# ## Plot the data

# %%
df.plot(y=['Close', 'S_' + str(timeperiod.value)], labels={'value':'Value', 'index':'Date', 'variable':'Variables'}) # Plot the close price and the rolling mean
# Out:
# <div>                            <div id="a506b7bb-a8ee-4e35-809d-85b6651f3adf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a506b7bb-a8ee-4e35-809d-85b6651f3adf")) {                    Plotly.newPlot(                        "a506b7bb-a8ee-4e35-809d-85b6651f3adf",                        [{"hovertemplate":"Variables=Close<br>Date=%{x}<br>Value=%{y}<extra></extra>","legendgroup":"Close","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Close","showlegend":true,"x":["2000-02-22T00:00:00","2000-02-23T00:00:00","2000-02-24T00:00:00","2000-02-25T00:00:00","2000-02-28T00:00:00","2000-02-29T00:00:00","2000-03-01T00:00:00","2000-03-02T00:00:00","2000-03-03T00:00:00","2000-03-06T00:00:00","2000-03-07T00:00:00","2000-03-08T00:00:00","2000-03-09T00:00:00","2000-03-10T00:00:00","2000-03-13T00:00:00","2000-03-14T00:00:00","2000-03-15T00:00:00","2000-03-16T00:00:00","2000-03-17T00:00:00","2000-03-20T00:00:00","2000-03-21T00:00:00","2000-03-22T00:00:00","2000-03-23T00:00:00","2000-03-24T00:00:00","2000-03-27T00:00:00","2000-03-28T00:00:00","2000-03-29T00:00:00","2000-03-30T00:00:00","2000-03-31T00:00:00","2000-04-03T00:00:00","2000-04-04T00:00:00","2000-04-05T00:00:00","2000-04-06T00:00:00","2000-04-07T00:00:00","2000-04-10T00:00:00","2000-04-11T00:00:00","2000-04-12T00:00:00","2000-04-13T00:00:00","2000-04-14T00:00:00","2000-04-17T00:00:00","2000-04-18T00:00:00","2000-04-19T00:00:00","2000-04-20T00:00:00","2000-04-21T00:00:00","2000-04-24T00:00:00","2000-04-25T00:00:00","2000-04-26T00:00:00","2000-04-27T00:00:00","2000-04-28T00:00:00","2000-05-01T00:00:00","2000-05-02T00:00:00","2000-05-03T00:00:00","2000-05-04T00:00:00","2000-05-05T00:00:00","2000-05-08T00:00:00","2000-05-09T00:00:00","2000-05-10T00:00:00","2000-05-11T00:00:00","2000-05-12T00:00:00","2000-05-15T00:00:00","2000-05-16T00:00:00","2000-05-17T00:00:00","2000-05-18T00:00:00","2000-05-19T00:00:00","2000-05-22T00:00:00","2000-05-23T00:00:00","2000-05-24T00:00:00","2000-05-25T00:00:00","2000-05-26T00:00:00","2000-05-29T00:00:00","2000-05-30T00:00:00","2000-05-31T00:00:00","2000-06-01T00:00:00","2000-06-02T00:00:00","2000-06-05T00:00:00","2000-06-06T00:00:00","2000-06-07T00:00:00","2000-06-08T00:00:00","2000-06-09T00:00:00","2000-06-12T00:00:00","2000-06-13T00:00:00","2000-06-14T00:00:00","2000-06-15T00:00:00","2000-06-16T00:00:00","2000-06-19T00:00:00","2000-06-20T00:00:00","2000-06-21T00:00:00","2000-06-22T00:00:00","2000-06-23T00:00:00","2000-06-26T00:00:00","2000-06-27T00:00:00","2000-06-28T00:00:00","2000-06-29T00:00:00","2000-06-30T00:00:00","2000-07-03T00:00:00","2000-07-04T00:00:00","2000-07-05T00:00:00","2000-07-06T00:00:00","2000-07-07T00:00:00","2000-07-10T00:00:00","2000-07-11T00:00:00","2000-07-12T00:00:00","2000-07-13T00:00:00","2000-07-14T00:00:00","2000-07-17T00:00:00","2000-07-18T00:00:00","2000-07-19T00:00:00","2000-07-20T00:00:00","2000-07-21T00:00:00","2000-07-24T00:00:00","2000-07-25T00:00:00","2000-07-26T00:00:00","2000-07-27T00:00:00","2000-07-28T00:00:00","2000-07-31T00:00:00","2000-08-01T00:00:00","2000-08-02T00:00:00","2000-08-03T00:00:00","2000-08-04T00:00:00","2000-08-07T00:00:00","2000-08-08T00:00:00","2000-08-09T00:00:00","2000-08-10T00:00:00","2000-08-11T00:00:00","2000-08-14T00:00:00","2000-08-15T00:00:00","2000-08-16T00:00:00","2000-08-17T00:00:00","2000-08-18T00:00:00","2000-08-21T00:00:00","2000-08-22T00:00:00","2000-08-23T00:00:00","2000-08-24T00:00:00","2000-08-25T00:00:00","2000-08-28T00:00:00","2000-08-29T00:00:00","2000-08-30T00:00:00","2000-08-31T00:00:00","2000-09-01T00:00:00","2000-09-04T00:00:00","2000-09-05T00:00:00","2000-09-06T00:00:00","2000-09-07T00:00:00","2000-09-08T00:00:00","2000-09-11T00:00:00","2000-09-12T00:00:00","2000-09-13T00:00:00","2000-09-14T ...

# %% [markdown]
# ### Plot Cumulative PSEi returns

# %%
Cumulative_PSEi_returns.plot(labels={'value':'Cumulative Returns', 'index':'Date', 'variable':'Variables'}) # Plot the cumulative PSEi returns
# Out:
# <div>                            <div id="2dc37912-542d-4bd4-a0b5-df753058b50a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dc37912-542d-4bd4-a0b5-df753058b50a")) {                    Plotly.newPlot(                        "2dc37912-542d-4bd4-a0b5-df753058b50a",                        [{"hovertemplate":"Variables=PSEi_returns<br>Date=%{x}<br>Cumulative Returns=%{y}<extra></extra>","legendgroup":"PSEi_returns","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PSEi_returns","showlegend":true,"x":["2018-08-28T00:00:00","2018-08-29T00:00:00","2018-08-30T00:00:00","2018-08-31T00:00:00","2018-09-03T00:00:00","2018-09-04T00:00:00","2018-09-05T00:00:00","2018-09-06T00:00:00","2018-09-07T00:00:00","2018-09-10T00:00:00","2018-09-11T00:00:00","2018-09-12T00:00:00","2018-09-13T00:00:00","2018-09-14T00:00:00","2018-09-17T00:00:00","2018-09-18T00:00:00","2018-09-19T00:00:00","2018-09-20T00:00:00","2018-09-21T00:00:00","2018-09-24T00:00:00","2018-09-25T00:00:00","2018-09-26T00:00:00","2018-09-27T00:00:00","2018-09-28T00:00:00","2018-10-01T00:00:00","2018-10-02T00:00:00","2018-10-03T00:00:00","2018-10-04T00:00:00","2018-10-05T00:00:00","2018-10-08T00:00:00","2018-10-09T00:00:00","2018-10-10T00:00:00","2018-10-11T00:00:00","2018-10-12T00:00:00","2018-10-15T00:00:00","2018-10-16T00:00:00","2018-10-17T00:00:00","2018-10-18T00:00:00","2018-10-19T00:00:00","2018-10-22T00:00:00","2018-10-23T00:00:00","2018-10-24T00:00:00","2018-10-25T00:00:00","2018-10-26T00:00:00","2018-10-29T00:00:00","2018-10-30T00:00:00","2018-10-31T00:00:00","2018-11-05T00:00:00","2018-11-06T00:00:00","2018-11-07T00:00:00","2018-11-08T00:00:00","2018-11-09T00:00:00","2018-11-12T00:00:00","2018-11-13T00:00:00","2018-11-14T00:00:00","2018-11-15T00:00:00","2018-11-16T00:00:00","2018-11-19T00:00:00","2018-11-20T00:00:00","2018-11-21T00:00:00","2018-11-22T00:00:00","2018-11-23T00:00:00","2018-11-26T00:00:00","2018-11-27T00:00:00","2018-11-28T00:00:00","2018-11-29T00:00:00","2018-12-03T00:00:00","2018-12-04T00:00:00","2018-12-05T00:00:00","2018-12-06T00:00:00","2018-12-07T00:00:00","2018-12-10T00:00:00","2018-12-11T00:00:00","2018-12-12T00:00:00","2018-12-13T00:00:00","2018-12-14T00:00:00","2018-12-17T00:00:00","2018-12-18T00:00:00","2018-12-19T00:00:00","2018-12-20T00:00:00","2018-12-21T00:00:00","2018-12-26T00:00:00","2018-12-27T00:00:00","2018-12-28T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-04T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-04-01T00:00:00", ...

# %% [markdown]
# ### Plot the Cumulative Strategy Returns

# %%
Cumulative_Strategy_returns.plot(labels={'value':'Cumulative Returns', 'index':'Date', 'variable':'Variables'}) # Plot the cumulative strategy returns
# Out:
# <div>                            <div id="121cce34-e951-46a2-a45c-106e2b4ba47c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("121cce34-e951-46a2-a45c-106e2b4ba47c")) {                    Plotly.newPlot(                        "121cce34-e951-46a2-a45c-106e2b4ba47c",                        [{"hovertemplate":"Variables=Strategy_Returns<br>Date=%{x}<br>Cumulative Returns=%{y}<extra></extra>","legendgroup":"Strategy_Returns","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Strategy_Returns","showlegend":true,"x":["2018-08-28T00:00:00","2018-08-29T00:00:00","2018-08-30T00:00:00","2018-08-31T00:00:00","2018-09-03T00:00:00","2018-09-04T00:00:00","2018-09-05T00:00:00","2018-09-06T00:00:00","2018-09-07T00:00:00","2018-09-10T00:00:00","2018-09-11T00:00:00","2018-09-12T00:00:00","2018-09-13T00:00:00","2018-09-14T00:00:00","2018-09-17T00:00:00","2018-09-18T00:00:00","2018-09-19T00:00:00","2018-09-20T00:00:00","2018-09-21T00:00:00","2018-09-24T00:00:00","2018-09-25T00:00:00","2018-09-26T00:00:00","2018-09-27T00:00:00","2018-09-28T00:00:00","2018-10-01T00:00:00","2018-10-02T00:00:00","2018-10-03T00:00:00","2018-10-04T00:00:00","2018-10-05T00:00:00","2018-10-08T00:00:00","2018-10-09T00:00:00","2018-10-10T00:00:00","2018-10-11T00:00:00","2018-10-12T00:00:00","2018-10-15T00:00:00","2018-10-16T00:00:00","2018-10-17T00:00:00","2018-10-18T00:00:00","2018-10-19T00:00:00","2018-10-22T00:00:00","2018-10-23T00:00:00","2018-10-24T00:00:00","2018-10-25T00:00:00","2018-10-26T00:00:00","2018-10-29T00:00:00","2018-10-30T00:00:00","2018-10-31T00:00:00","2018-11-05T00:00:00","2018-11-06T00:00:00","2018-11-07T00:00:00","2018-11-08T00:00:00","2018-11-09T00:00:00","2018-11-12T00:00:00","2018-11-13T00:00:00","2018-11-14T00:00:00","2018-11-15T00:00:00","2018-11-16T00:00:00","2018-11-19T00:00:00","2018-11-20T00:00:00","2018-11-21T00:00:00","2018-11-22T00:00:00","2018-11-23T00:00:00","2018-11-26T00:00:00","2018-11-27T00:00:00","2018-11-28T00:00:00","2018-11-29T00:00:00","2018-12-03T00:00:00","2018-12-04T00:00:00","2018-12-05T00:00:00","2018-12-06T00:00:00","2018-12-07T00:00:00","2018-12-10T00:00:00","2018-12-11T00:00:00","2018-12-12T00:00:00","2018-12-13T00:00:00","2018-12-14T00:00:00","2018-12-17T00:00:00","2018-12-18T00:00:00","2018-12-19T00:00:00","2018-12-20T00:00:00","2018-12-21T00:00:00","2018-12-26T00:00:00","2018-12-27T00:00:00","2018-12-28T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-04T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-04-0 ...

# %% [markdown]
# ### Plot the PSEi returns and the Strategy returns

# %%
Cumulative_PSEi_returns_df = Cumulative_PSEi_returns.to_frame()
Cumulative_Strategy_returns_df = Cumulative_Strategy_returns.to_frame()

cumulative_returns_df = pd.merge(Cumulative_PSEi_returns_df, Cumulative_Strategy_returns_df, left_index=True, right_index=True)
cumulative_returns_df.head()
# Out:
#             PSEi_returns  Strategy_Returns
# Date
# 2018-08-28      0.010011          0.010011
# 2018-08-29      0.008269          0.008269
# 2018-08-30      0.011100          0.011100
# 2018-08-31      0.011425          0.011425
# 2018-09-03      0.008430          0.008430

# %% [markdown]
# ### Plot

# %%
cumulative_returns_df.plot(title='PSEi amd Strategy Cumulative Returns', labels={'value':'Cumulative Returns', 'index':'Date', 'variable':'Strategy'})
# Out:
# <div>                            <div id="3dee6623-1fd3-4aa2-b0fa-d68901cfd06b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3dee6623-1fd3-4aa2-b0fa-d68901cfd06b")) {                    Plotly.newPlot(                        "3dee6623-1fd3-4aa2-b0fa-d68901cfd06b",                        [{"hovertemplate":"Strategy=PSEi_returns<br>Date=%{x}<br>Cumulative Returns=%{y}<extra></extra>","legendgroup":"PSEi_returns","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PSEi_returns","showlegend":true,"x":["2018-08-28T00:00:00","2018-08-29T00:00:00","2018-08-30T00:00:00","2018-08-31T00:00:00","2018-09-03T00:00:00","2018-09-04T00:00:00","2018-09-05T00:00:00","2018-09-06T00:00:00","2018-09-07T00:00:00","2018-09-10T00:00:00","2018-09-11T00:00:00","2018-09-12T00:00:00","2018-09-13T00:00:00","2018-09-14T00:00:00","2018-09-17T00:00:00","2018-09-18T00:00:00","2018-09-19T00:00:00","2018-09-20T00:00:00","2018-09-21T00:00:00","2018-09-24T00:00:00","2018-09-25T00:00:00","2018-09-26T00:00:00","2018-09-27T00:00:00","2018-09-28T00:00:00","2018-10-01T00:00:00","2018-10-02T00:00:00","2018-10-03T00:00:00","2018-10-04T00:00:00","2018-10-05T00:00:00","2018-10-08T00:00:00","2018-10-09T00:00:00","2018-10-10T00:00:00","2018-10-11T00:00:00","2018-10-12T00:00:00","2018-10-15T00:00:00","2018-10-16T00:00:00","2018-10-17T00:00:00","2018-10-18T00:00:00","2018-10-19T00:00:00","2018-10-22T00:00:00","2018-10-23T00:00:00","2018-10-24T00:00:00","2018-10-25T00:00:00","2018-10-26T00:00:00","2018-10-29T00:00:00","2018-10-30T00:00:00","2018-10-31T00:00:00","2018-11-05T00:00:00","2018-11-06T00:00:00","2018-11-07T00:00:00","2018-11-08T00:00:00","2018-11-09T00:00:00","2018-11-12T00:00:00","2018-11-13T00:00:00","2018-11-14T00:00:00","2018-11-15T00:00:00","2018-11-16T00:00:00","2018-11-19T00:00:00","2018-11-20T00:00:00","2018-11-21T00:00:00","2018-11-22T00:00:00","2018-11-23T00:00:00","2018-11-26T00:00:00","2018-11-27T00:00:00","2018-11-28T00:00:00","2018-11-29T00:00:00","2018-12-03T00:00:00","2018-12-04T00:00:00","2018-12-05T00:00:00","2018-12-06T00:00:00","2018-12-07T00:00:00","2018-12-10T00:00:00","2018-12-11T00:00:00","2018-12-12T00:00:00","2018-12-13T00:00:00","2018-12-14T00:00:00","2018-12-17T00:00:00","2018-12-18T00:00:00","2018-12-19T00:00:00","2018-12-20T00:00:00","2018-12-21T00:00:00","2018-12-26T00:00:00","2018-12-27T00:00:00","2018-12-28T00:00:00","2019-01-02T00:00:00","2019-01-03T00:00:00","2019-01-04T00:00:00","2019-01-07T00:00:00","2019-01-08T00:00:00","2019-01-09T00:00:00","2019-01-10T00:00:00","2019-01-11T00:00:00","2019-01-14T00:00:00","2019-01-15T00:00:00","2019-01-16T00:00:00","2019-01-17T00:00:00","2019-01-18T00:00:00","2019-01-21T00:00:00","2019-01-22T00:00:00","2019-01-23T00:00:00","2019-01-24T00:00:00","2019-01-25T00:00:00","2019-01-28T00:00:00","2019-01-29T00:00:00","2019-01-30T00:00:00","2019-01-31T00:00:00","2019-02-01T00:00:00","2019-02-04T00:00:00","2019-02-06T00:00:00","2019-02-07T00:00:00","2019-02-08T00:00:00","2019-02-11T00:00:00","2019-02-12T00:00:00","2019-02-13T00:00:00","2019-02-14T00:00:00","2019-02-15T00:00:00","2019-02-18T00:00:00","2019-02-19T00:00:00","2019-02-20T00:00:00","2019-02-21T00:00:00","2019-02-22T00:00:00","2019-02-26T00:00:00","2019-02-27T00:00:00","2019-02-28T00:00:00","2019-03-01T00:00:00","2019-03-04T00:00:00","2019-03-05T00:00:00","2019-03-06T00:00:00","2019-03-07T00:00:00","2019-03-08T00:00:00","2019-03-11T00:00:00","2019-03-12T00:00:00","2019-03-13T00:00:00","2019-03-14T00:00:00","2019-03-15T00:00:00","2019-03-18T00:00:00","2019-03-19T00:00:00","2019-03-20T00:00:00","2019-03-21T00:00:00","2019-03-22T00:00:00","2019-03-25T00:00:00","2019-03-26T00:00:00","2019-03-27T00:00:00","2019-03-28T00:00:00","2019-03-29T00:00:00","2019-04-01T00:00:00"," ...

# %%
cumulative_returns_df.to_csv('cumulative_returns.csv') # Output the data to CSV
